# %% [markdown]
# # Tugas Kelompok

# %% [markdown]
# Download data disini :

# %% [markdown]
# https://drive.google.com/file/d/1yRYkjsF9CuC4RXueZQCHuJnXRSXliBjS/view?usp=sharing

# %% [markdown]
# Langkah dalam menyelesaikan tugas ini adalah:
#
# * Buatlah terlebih dahulu list dictionary yang kosong
#
# * Buatlah looping untuk melakukan kalkulasi dengan fungsi Map atau Filter atau Reduce kemudian simpan ke dalam list dictionary yang sudah di definisikan

# %% [markdown]
# Bagian 1: Model Populasi Polisi Detroit
#
# Baca data dari file Laporan Polisi Detroit menggunakan modul csv dan terjemahkan data ke dalam daftar dictionary. Menggunakan Filter dengan fungsi lambda untuk mengecualikan dictionary (baris CSV) yang memiliki data yang hilang di kolom Zip, atau kolom Neighborhood. Dengan menggunakan fungsi lambda dan Reduce, hitung total waktu respons rata-rata, waktu pengiriman rata-rata, dan total waktu rata-rata untuk kepolisian Detroit.

# %% [markdown]
# Bagian 2: Modelkan Neighborhood Samples
#
# Menggunakan fungsi lambda dan map, atau lambda dan Filter, bagi list dictionary menjadi list dictionary yang lebih kecil yang dipisahkan oleh neighborhood. Dengan menggunakan lambda dan Reduce, temukan total waktu respons rata-rata untuk setiap neighborhood, waktu pengiriman rata-rata untuk setiap neighborhood, dan total waktu rata-rata untuk setiap neighborhood dan simpanlah ke dalam list dictionary. Tambahkan item dictioanary untuk menyertakan data populasi untuk semua Detroit dalam daftar gabungan Anda.

# %% [markdown]
# Bagian 3: Buat file Output JSON
#
# Menggunakan modul JSON, format list dictionary Anda sebagai JSON

# %%
# List dictionary kosong untuk menyimpan data
list_dictionary = []

# %%
import csv
import sys
from functools import reduce

# Fungsi untuk membaca data dari file CSV dan menerjemahkannya ke dalam daftar dictionary
def baca_data(file_path):
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        data_list = [row for row in reader]
    return data_list

# Minta pengguna untuk memasukkan nama file CSV
file_path = input("Masukkan nama file CSV: ")

# Baca data dari file CSV dan menerjemahkannya ke dalam daftar dictionary
data_polisi_detroit = baca_data(file_path)
# Out:
# Masukkan nama file CSV: 911_Calls_for_Service_(Last_30_Days).csv

# %%
# Fungsi untuk menghitung total respons time dari suatu data
def hitung_total_respons(data):
    total_respons_time = data['totalresponsetime']
    return float(total_respons_time) if total_respons_time else 0.0

# Melakukan kalkulasi menggunakan fungsi map
total_respons_per_data = list(map(hitung_total_respons, data_polisi_detroit))

# Simpan hasil ke dalam list dictionary
for index, data in enumerate(data_polisi_detroit):
    list_dictionary.append({
        'index': index,
        'total_respons': total_respons_per_data[index]
    })

# Tampilkan hasil
print(list_dictionary)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#Bagian 1: Model Populasi Polisi Detroit

# Filter untuk mengecualikan baris dengan data yang hilang di kolom Zip atau kolom Neighborhood
data_polisi_detroit = list(filter(lambda x: x['zip_code'] != '' and x['neighborhood'] != '', data_polisi_detroit))

# Fungsi lambda untuk menghitung total waktu respons, waktu pengiriman, dan total waktu
total_respons = reduce(lambda x, y: x + float(y['totalresponsetime']) if y['totalresponsetime'] else x, data_polisi_detroit, 0)
total_pengiriman = reduce(lambda x, y: x + float(y['dispatchtime']) if y['dispatchtime'] else x, data_polisi_detroit, 0)
total_waktu = reduce(lambda x, y: x + float(y['totaltime']) if y['totaltime'] else x, data_polisi_detroit, 0)

# Hitung rata-rata waktu respons, waktu pengiriman, dan total waktu
rata_respons = total_respons / len(data_polisi_detroit)
rata_pengiriman = total_pengiriman / len(data_polisi_detroit)
rata_waktu = total_waktu / len(data_polisi_detroit)

# Tampilkan hasil
print("Total waktu respons rata-rata untuk kepolisian Detroit:", rata_respons)
print("Total waktu pengiriman rata-rata untuk kepolisian Detroit:", rata_pengiriman)
print("Total waktu rata-rata untuk kepolisian Detroit:", rata_waktu)
# Out:
# Total waktu respons rata-rata untuk kepolisian Detroit: 8.023254124066208
# Total waktu pengiriman rata-rata untuk kepolisian Detroit: 4.768282297748636
# Total waktu rata-rata untuk kepolisian Detroit: 28.634880548686127

# %%
#Bagian 2: Modelkan Neighborhood Samples

from functools import reduce

# Fungsi lambda untuk memisahkan data berdasarkan neighborhood
separate_neighborhood = lambda neighborhood, data: list(filter(lambda x: x["neighborhood"] == neighborhood, data))

# Fungsi lambda untuk menghitung total waktu respons rata-rata
calculate_avg_response_time = lambda acc, item: acc + (float(item["totalresponsetime"]) if item["totalresponsetime"] else 0) / len(data_polisi_detroit)

# Fungsi lambda untuk menghitung total waktu pengiriman rata-rata
calculate_avg_delivery_time = lambda acc, item: acc + (float(item["traveltime"]) if item["traveltime"] else 0) / len(data_polisi_detroit)

# Fungsi lambda untuk menghitung total waktu rata-rata
calculate_avg_total_time = lambda acc, item: acc + ((float(item["totalresponsetime"]) if item["totalresponsetime"] else 0) + (float(item["traveltime"]) if item["traveltime"] else 0)) / len(data_polisi_detroit)

# Memisahkan data berdasarkan neighborhood
neighborhoods_data = list(map(lambda x: separate_neighborhood(x, data_polisi_detroit), set(map(lambda x: x["neighborhood"], data_polisi_detroit))))

# Menghitung total waktu respons rata-rata, waktu pengiriman rata-rata, dan total waktu rata-rata untuk setiap neighborhood
results = []
for neighborhood_data in neighborhoods_data:
    avg_response_time = round(reduce(calculate_avg_response_time, neighborhood_data, 0), 2)
    avg_delivery_time = round(reduce(calculate_avg_delivery_time, neighborhood_data, 0), 2)
    avg_total_time = round(reduce(calculate_avg_total_time, neighborhood_data, 0), 2)
    results.append({
        "neighborhood": neighborhood_data[0]["neighborhood"],
        "avg_response_time": avg_response_time,
        "avg_delivery_time": avg_delivery_time,
        "avg_total_time": avg_total_time
    })

# Menambahkan data populasi untuk semua Detroit ke dalam daftar gabungan
results.append({"neighborhood": "Detroit", "population": "Data populasi Detroit"})

# Output hasil
print(results)
# Out:
# [{'neighborhood': '', 'avg_response_time': 0.15, 'avg_delivery_time': 0.04, 'avg_total_time': 0.19}, {'neighborhood': 'Penrose', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.01}, {'neighborhood': 'Douglass', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.01}, {'neighborhood': 'Rouge Park', 'avg_response_time': 0.0, 'avg_delivery_time': 0.0, 'avg_total_time': 0.0}, {'neighborhood': 'Minock Park', 'avg_response_time': 0.02, 'avg_delivery_time': 0.0, 'avg_total_time': 0.02}, {'neighborhood': 'Dexter-Linwood', 'avg_response_time': 0.15, 'avg_delivery_time': 0.04, 'avg_total_time': 0.19}, {'neighborhood': 'Gratiot Woods', 'avg_response_time': 0.06, 'avg_delivery_time': 0.0, 'avg_total_time': 0.06}, {'neighborhood': 'Tri-Point', 'avg_response_time': 0.0, 'avg_delivery_time': 0.0, 'avg_total_time': 0.0}, {'neighborhood': 'Palmer Woods', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.02}, {'neighborhood': 'East English Village', 'avg_response_time': 0.04, 'avg_delivery_time': 0.01, 'avg_total_time': 0.04}, {'neighborhood': 'Midtown', 'avg_response_time': 0.16, 'avg_delivery_time': 0.05, 'avg_total_time': 0.21}, {'neighborhood': 'Nortown', 'avg_response_time': 0.06, 'avg_delivery_time': 0.01, 'avg_total_time': 0.07}, {'neighborhood': 'We Care Community', 'avg_response_time': 0.06, 'avg_delivery_time': 0.01, 'avg_total_time': 0.07}, {'neighborhood': 'Hubbard Farms', 'avg_response_time': 0.0, 'avg_delivery_time': 0.0, 'avg_total_time': 0.01}, {'neighborhood': 'Barton-McFarland', 'avg_response_time': 0.21, 'avg_delivery_time': 0.04, 'avg_total_time': 0.25}, {'neighborhood': 'Riverbend', 'avg_response_time': 0.03, 'avg_delivery_time': 0.01, 'avg_total_time': 0.03}, {'neighborhood': 'North Rosedale Park', 'avg_response_time': 0.02, 'avg_delivery_time': 0.01, 'avg_total_time': 0.03}, {'neighborhood': 'Chadsey Condon', 'avg_response_time': 0.04, 'avg_delivery_time': 0.01, 'avg_total_time': 0.05}, {'neighborhood': 'Garden Homes', 'avg_response_time': 0.03, 'avg_delivery_time': 0.0, 'avg_total_time': 0.03}, {'neighborhood': 'Petoskey-Otsego', 'avg_response_time': 0.03, 'avg_delivery_time': 0.01, 'avg_total_time': 0.03}, {'neighborhood': 'Corktown', 'avg_response_time': 0.04, 'avg_delivery_time': 0.02, 'avg_total_time': 0.06}, {'neighborhood': 'Joy Community', 'avg_response_time': 0.12, 'avg_delivery_time': 0.04, 'avg_total_time': 0.15}, {'neighborhood': 'Von Steuben', 'avg_response_time': 0.05, 'avg_delivery_time': 0.01, 'avg_total_time': 0.06}, {'neighborhood': 'Poletown East', 'avg_response_time': 0.05, 'avg_delivery_time': 0.03, 'avg_total_time': 0.07}, {'neighborhood': 'Cornerstone Village', 'avg_response_time': 0.13, 'avg_delivery_time': 0.04, 'avg_total_time': 0.17}, {'neighborhood': 'New Center', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.01}, {'neighborhood': 'Garden View', 'avg_response_time': 0.03, 'avg_delivery_time': 0.0, 'avg_total_time': 0.03}, {'neighborhood': 'Grand River-St Marys', 'avg_response_time': 0.03, 'avg_delivery_time': 0.01, 'avg_total_time': 0.04}, {'neighborhood': 'Castle Rouge', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.01}, {'neighborhood': 'Cadillac Community', 'avg_response_time': 0.03, 'avg_delivery_time': 0.0, 'avg_total_time': 0.03}, {'neighborhood': 'Sherwood', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.01}, {'neighborhood': 'Pembroke', 'avg_response_time': 0.02, 'avg_delivery_time': 0.01, 'avg_total_time': 0.03}, {'neighborhood': 'North Campau', 'avg_response_time': 0.01, 'avg_delivery_time': 0.0, 'avg_total_time': 0.02}, {'neighborhood': 'Oak Grove', 'avg_response_time': 0.04, 'avg_delivery_time': 0.01, 'avg_total_time': 0.04}, {'neighborhood': 'Wildemere Park', 'avg_response_time': 0.03, 'avg_delivery_time': 0.0, 'avg_total_time': 0.03}, {'neighborhood': 'East Canfield', 'avg_response_time': 0.0, 'avg_delivery_time': 0.0, 'avg_total_time ...

# %%
#Bagian 2# Memisahkan list dictionary berdasarkan neighborhood menggunakan fungsi lambda dan filter
# Memisahkan list dictionary berdasarkan neighborhood menggunakan fungsi lambda dan map
neighborhood_samples = {}

# Fungsi untuk memisahkan data berdasarkan neighborhood
def split_by_neighborhood(data):
    neighborhoods = set(map(lambda x: x['neighborhood'], data))
    for neighborhood in neighborhoods:
        neighborhood_samples[neighborhood] = list(filter(lambda x: x['neighborhood'] == neighborhood, data))

# %%
# Memanggil fungsi untuk memisahkan data berdasarkan neighborhood
split_by_neighborhood(data_polisi_detroit)

# %%
from functools import reduce

# Fungsi lambda dan Reduce untuk menghitung total waktu respons, waktu pengiriman, dan total waktu untuk setiap neighborhood
for neighborhood, samples in neighborhood_samples.items():
    total_respons = reduce(lambda x, y: x + float(y['totalresponsetime']) if 'totalresponsetime' in y and y['totalresponsetime'] else x, samples, 0)
    total_pengiriman = reduce(lambda x, y: x + float(y['dispatchtime']) if 'dispatchtime' in y and y['dispatchtime'] else x, samples, 0)
    total_waktu = reduce(lambda x, y: x + float(y['totaltime']) if 'totaltime' in y and y['totaltime'] else x, samples, 0)
    rata_respons = total_respons / len(samples)
    rata_pengiriman = total_pengiriman / len(samples)
    rata_waktu = total_waktu / len(samples)
    neighborhood_samples[neighborhood]['total_respons_rata_rata'] = rata_respons
    neighborhood_samples[neighborhood]['total_pengiriman_rata_rata'] = rata_pengiriman
    neighborhood_samples[neighborhood]['total_waktu_rata_rata'] = rata_waktu

# Menambahkan item dictionary untuk menyertakan data populasi untuk seluruh Detroit dalam daftar gabungan
total_respons_detroit = sum(float(sample['totalresponsetime']) if 'totalresponsetime' in sample and sample['totalresponsetime'] else 0 for sample in data_polisi_detroit)
total_pengiriman_detroit = sum(float(sample['dispatchtime']) if 'dispatchtime' in sample and sample['dispatchtime'] else 0 for sample in data_polisi_detroit)
total_waktu_detroit = sum(float(sample['totaltime']) if 'totaltime' in sample and sample['totaltime'] else 0 for sample in data_polisi_detroit)
rata_respons_detroit = total_respons_detroit / len(data_polisi_detroit)
rata_pengiriman_detroit = total_pengiriman_detroit / len(data_polisi_detroit)
rata_waktu_detroit = total_waktu_detroit / len(data_polisi_detroit)

neighborhood_samples['All Detroit'] = {
    'total_respons_rata_rata': rata_respons_detroit,
    'total_pengiriman_rata_rata': rata_pengiriman_detroit,
    'total_waktu_rata_rata': rata_waktu_detroit
}

# Tampilkan hasil
print("Hasil perhitungan untuk setiap neighborhood:")
for neighborhood, data in neighborhood_samples.items():
    print(f"Neighborhood: {neighborhood}")
    print(f"Total waktu respons rata-rata: {data['total_respons_rata_rata']}")
    print(f"Total waktu pengiriman rata-rata: {data['total_pengiriman_rata_rata']}")
    print(f"Total waktu rata-rata: {data['total_waktu_rata_rata']}")
    print()
# Out:
# Hasil perhitungan untuk setiap neighborhood:
# Neighborhood: Grandmont #1
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Dexter-Fenkell
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Petoskey-Otsego
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Gratiot Town/Ketterring
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Plymouth-Hubbell
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Wildemere Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: McDougall-Hunt
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Berg-Lahser
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Medical Center
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: New Center
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Krainz Woods
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Milwaukee Junction
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: West Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Hubbell-Lyndon
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Marina District
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Chadsey Condon
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: College Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Denby
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Pershing
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Blackstone Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Boynton
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Paveway
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Campau/Banglatown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Gold Coast
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Poletown East
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Rivertown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Conner Creek
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Henry Ford
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Core City
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: New Center Commons
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Pride Area Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Michigan-Martin
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Gratiot-Findlay
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Warren Ave Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Weatherby
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Eden Gardens
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Hawthorne Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: We Care Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Castle Rouge
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Five Points
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Brush Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Hubbard Farms
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Eliza Howell
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Detroit Golf
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Minock Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Evergreen-Outer Drive
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Rosedale Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: O'Hair Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Moross-Morang
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Outer Drive-Hayes
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Grixdale Farms
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: North Rosedale Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Rouge Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Holcomb Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Miller Grove
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Indian Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Waterworks Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Jamison
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Delray
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Chandler Park-Chalmers
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Chalfonte
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Chandler Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Sherwood Forest
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Pembroke
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Cadillac Heights
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Oakwood Heights
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: San Bernardo
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Davison-Schoolcraft
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Jeffries
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: North LaSalle
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Bagley
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Garden View
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Midtown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: North Corktown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Piety Hill
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Mohican Regent
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Fox Creek
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Carbon Works
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Belle Isle
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Nolan
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Sherwood
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Seven Mile Lodge
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Grant
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Conant Gardens
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Wayne State
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Airport Sub
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: LaSalle Gardens
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Littlefield Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Dexter-Linwood
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Joy Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Greenfield Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Lafayette Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Butler
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Virginia Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Cultural Center
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Hubbell-Puritan
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Hubbard Richard
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: West Outer Drive
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Warrendale
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: South of Six
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Elijah McCoy
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: The Eye
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Schulze
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Plymouth-I96
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Greenfield
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Grand River-I96
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Garden Homes
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Tri-Point
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Joy-Schaefer
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Belmont
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Russell Woods
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Corktown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: McNichols Evergreen
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Greenfield-Grand River
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Westwood Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Riverbend
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Historic Atkinson
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Forest Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Davison
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Tech Town
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Mexicantown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Brightmoor
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Mapleridge
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Brewster Homes
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Old Redford
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Nortown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Downtown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Martin Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Boston Edison
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Palmer Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Regent Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Gratiot Woods
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Schoolcraft Southfield
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Claytown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Seven Mile-Rouge
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Pilgrim Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Mount Olivet
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Medbury Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: West Virginia Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Pulaski
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Midwest
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Happy Homes
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Greenwich
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: NW Goldberg
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Fitzgerald/Marygrove
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: University District
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Cornerstone Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Eastern Market
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: East Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Grand River-St Marys
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Russell Industrial
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Bethune Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Farwell
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Islandview
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Far West Detroit
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Fiskhorn
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Schaefer 7/8 Lodge
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Green Acres
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Barton-McFarland
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Oakman Blvd Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Melvern Hill
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Northwest Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Oak Grove
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Morningside
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: State Fair
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Greektown
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Crary/St Marys
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: West Side Industrial
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Winship
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Joseph Berry Sub
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Grandmont
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Herman Kiefer
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Douglass
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Arden Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: North End
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Penrose
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Northeast Central District
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Evergreen Lahser 7/8
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Gratiot-Grand
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Yorkshire Woods
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Pingree Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Buffalo Charles
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Jefferson Chalmers
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: West End
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Woodbridge
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: East English Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Von Steuben
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Palmer Woods
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: East Canfield
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Wade
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Franklin
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Nardin Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Aviation Sub
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Springwells
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Southfield Plymouth
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Elmwood Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Central Southwest
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: North Campau
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: McDowell
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Riverdale
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Harmony Village
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Cadillac Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Gateway Community
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: LaSalle College Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Conner Creek Industrial
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Franklin Park
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: Ravendale
# Total waktu respons rata-rata: 0.0
# Total waktu pengiriman rata-rata: 0.0
# Total waktu rata-rata: 0.0
#
# Neighborhood: All Detroit
# Total waktu respons rata-rata: 8.023254124066208
# Total waktu pengiriman rata-rata: 4.768282297748636
# Total waktu rata-rata: 28.634880548686127

# %%
#Nomor 3
import json

# Simpan list dictionary sebagai file JSON
with open('output.json', 'w') as file:
    json.dump(neighborhood_samples, file)

print("Data telah disimpan sebagai file JSON.")
# Out:
# Data telah disimpan sebagai file JSON.
